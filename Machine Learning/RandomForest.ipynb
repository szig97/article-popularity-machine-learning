# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
import pandas as pd

# %%
premise_file = "../Data/cleaneddata.csv"
premise_df = pd.read_csv(premise_file)
premise_df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  http://mashable.com/2013/01/07/amazon-instant-...
# 1           1  http://mashable.com/2013/01/07/ap-samsung-spon...
# 2           2  http://mashable.com/2013/01/07/apple-40-billio...
# 3           3  http://mashable.com/2013/01/07/astronaut-notre...
# 4           4   http://mashable.com/2013/01/07/att-u-verse-apps/
#
#    Title_Word_Count  Content_Word_Count  Unique_Word_Rate  Non_Stop_Word_Rate  \
# 0              12.0               219.0          0.663594                 1.0
# 1               9.0               255.0          0.604743                 1.0
# 2               9.0               211.0          0.575130                 1.0
# 3               9.0               531.0          0.503788                 1.0
# 4              13.0              1072.0          0.415646                 1.0
#
#    Unique_Non_Stop_Word_Rate  Number_of_Links  Number_of_Mashable_Links  \
# 0                   0.815385              4.0                       2.0
# 1                   0.791946              3.0                       1.0
# 2                   0.663866              3.0                       1.0
# 3                   0.665635              9.0                       0.0
# 4                   0.540890             19.0                      19.0
#
#    Images  ...  Maximum_Positive_Polarity  Average_Negative_Polarity  \
# 0     1.0  ...                        0.7                  -0.350000
# 1     1.0  ...                        0.7                  -0.118750
# 2     1.0  ...                        1.0                  -0.466667
# 3     1.0  ...                        0.8                  -0.369697
# 4    20.0  ...                        1.0                  -0.220192
#
#    Minimum_Negative_Polarity  Maximum_Negative_Polarity  Title_Subjectivity  \
# 0                     -0.600                  -0.200000            0.500000
# 1                     -0.125                  -0.100000            0.000000
# 2                     -0.800                  -0.133333            0.000000
# 3                     -0.600                  -0.166667            0.000000
# 4                     -0.500                  -0.050000            0.454545
#
#    Title_Polarity  Absolute_Subjectivity_Level  Absolute_Polarity_Level  \
# 0       -0.187500                     0.000000                 0.187500
# 1        0.000000                     0.500000                 0.000000
# 2        0.000000                     0.500000                 0.000000
# 3        0.000000                     0.500000                 0.000000
# 4        0.136364                     0.045455                 0.136364
#
#    Shares          Category
# 0     593    Very Unpopular
# 1     711    Very Unpopular
# 2    1500  Somewhat Popular
# 3    1200         Unpopular
# 4     505    Very Unpopular
#
# [5 rows x 62 columns]

# %%
data=premise_df.drop(["Unnamed: 0", "url", "Shares", "Category"], axis=1)
data.head()
# Out:
#    Title_Word_Count  Content_Word_Count  Unique_Word_Rate  Non_Stop_Word_Rate  \
# 0              12.0               219.0          0.663594                 1.0
# 1               9.0               255.0          0.604743                 1.0
# 2               9.0               211.0          0.575130                 1.0
# 3               9.0               531.0          0.503788                 1.0
# 4              13.0              1072.0          0.415646                 1.0
#
#    Unique_Non_Stop_Word_Rate  Number_of_Links  Number_of_Mashable_Links  \
# 0                   0.815385              4.0                       2.0
# 1                   0.791946              3.0                       1.0
# 2                   0.663866              3.0                       1.0
# 3                   0.665635              9.0                       0.0
# 4                   0.540890             19.0                      19.0
#
#    Images  Videos  Average_Word_Length  ...  Average_Positive_Polarity  \
# 0     1.0     0.0             4.680365  ...                   0.378636
# 1     1.0     0.0             4.913725  ...                   0.286915
# 2     1.0     0.0             4.393365  ...                   0.495833
# 3     1.0     0.0             4.404896  ...                   0.385965
# 4    20.0     0.0             4.682836  ...                   0.411127
#
#    Minimum_Positive_Polarity  Maximum_Positive_Polarity  \
# 0                   0.100000                        0.7
# 1                   0.033333                        0.7
# 2                   0.100000                        1.0
# 3                   0.136364                        0.8
# 4                   0.033333                        1.0
#
#    Average_Negative_Polarity  Minimum_Negative_Polarity  \
# 0                  -0.350000                     -0.600
# 1                  -0.118750                     -0.125
# 2                  -0.466667                     -0.800
# 3                  -0.369697                     -0.600
# 4                  -0.220192                     -0.500
#
#    Maximum_Negative_Polarity  Title_Subjectivity  Title_Polarity  \
# 0                  -0.200000            0.500000       -0.187500
# 1                  -0.100000            0.000000        0.000000
# 2                  -0.133333            0.000000        0.000000
# 3                  -0.166667            0.000000        0.000000
# 4                  -0.050000            0.454545        0.136364
#
#    Absolute_Subjectivity_Level  Absolute_Polarity_Level
# 0                     0.000000                 0.187500
# 1                     0.500000                 0.000000
# 2                     0.500000                 0.000000
# 3                     0.500000                 0.000000
# 4                     0.045455                 0.136364
#
# [5 rows x 58 columns]

# %%
target=premise_df["Category"]
target.head()
# Out:
# 0      Very Unpopular
# 1      Very Unpopular
# 2    Somewhat Popular
# 3           Unpopular
# 4      Very Unpopular
# Name: Category, dtype: object
